# %% [markdown]
# ># Create models for Ocean Depths model
#
# >- October, 2021. S. Chakraborty (<shibaji7@vt.edu>)
#
# >> ### Simplified 1D Ocean depth model: conductivity changes with depth only

# %%
# Import required parameters
import numpy as np
import matplotlib.pyplot as plt
plt.style.use(["science", "ieee"])
import models

# %%
spo = models.SimpleParabolicOcean(verbose=True)
fig = plt.figure(dpi=150, figsize=(5,3))
ax = fig.add_subplot(111)
spo.plot_ocean_basin(ax)
spo.create_basin_tf()
# Out:
#  Total processes (nprocs): 51(24)
#  Calculate transfer functions for location, depths: -4.80, 0.39
#  Calculate transfer functions for location, depths: -5.00, 0.00
#  Calculate transfer functions for location, depths: -4.60, 0.77
#  Calculate transfer functions for location, depths: -3.80, 2.11
#  Calculate transfer functions for location, depths: -4.00, 1.80
#  Calculate transfer functions for location, depths: -3.60, 2.41
#  Calculate transfer functions for location, depths: -2.60, 3.65
#  Calculate transfer functions for location, depths: -4.40, 1.13
#  Calculate transfer functions for location, depths: -2.40, 3.85
#  Calculate transfer functions for location, depths: -2.20, 4.03
#  Calculate transfer functions for location, depths: -0.80, 4.87
#  Calculate transfer functions for location, depths: -3.40, 2.69
#  Calculate transfer functions for location, depths: -1.80, 4.35
#  Calculate transfer functions for location, depths: -4.20, 1.47
# ...

# %%
fig = plt.figure(dpi=150, figsize=(8,3))
spo.contour_plots(fig.add_subplot(121))
spo.contour_plots(fig.add_subplot(122), param="TF.Ed2Ho:mag", label=r"$|\frac{E_d}{B_o}|$")

# %%
cd = models.CableDetails()
cd.get_ocean_depth_data()
cd.create_basin_tf()
cd.plot_cable_footprint()

# %%
cd = models.CableDetails(cable_file="data/TAT-8.cable", cables=["TAT-8"])
cd.create_basin_tf()
cd.plot_TF_location()
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %%
from get_data import *
frames = download_magnetometer_data_by_stations_dates(dt.datetime(2017,9,6,11), dt.datetime(2017,9,6,14,1), ["STJ"])
plotB(frames)

# %%
Bf_frames = Btime2Bfreq(frames, component="E")
plotBf(Bf_frames)
